# %% [markdown]
# <a href="https://colab.research.google.com/github/ninjamoba/question_generator/blob/master/siaquestions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/amontgomerie/question_generator
# Out:
# Cloning into 'question_generator'...
# remote: Enumerating objects: 248, done.
# remote: Counting objects: 100% (136/136), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 248 (delta 72), reused 103 (delta 63), pack-reused 112
# Receiving objects: 100% (248/248), 114.53 KiB | 2.34 MiB/s, done.
# Resolving deltas: 100% (127/127), done.

# %%
# %cd question_generator
# Out:
# /content/question_generator

# %%
# !pip install -r requirements.txt -qq
# Out:
#      |████████████████████████████████| 12.0 MB 5.3 MB/s
#      |████████████████████████████████| 298 kB 5.3 MB/s
#      |████████████████████████████████| 1.2 MB 44.9 MB/s
#      |████████████████████████████████| 9.9 MB 17.6 MB/s
#      |████████████████████████████████| 3.3 MB 41.1 MB/s
#      |████████████████████████████████| 776.8 MB 18 kB/s
#      |████████████████████████████████| 3.1 MB 37.8 MB/s
#      |████████████████████████████████| 133 kB 50.9 MB/s
#      |████████████████████████████████| 1.1 MB 42.3 MB/s
#      |████████████████████████████████| 67 kB 5.0 MB/s
#      |████████████████████████████████| 243 kB 52.2 MB/s
#      |████████████████████████████████| 2.1 MB 41.0 MB/s
#      |████████████████████████████████| 596 kB 46.2 MB/s
#      |████████████████████████████████| 895 kB 49.1 MB/s
#      |████████████████████████████████| 271 kB 48.9 MB/s
#      |████████████████████████████████| 144 kB 51.8 MB/s
#      |████████████████████████████████| 94 kB 3.2 MB/s
# ...

# %%
# !python run_qg.py --text_file articles/shortclimateanswers.txt
# Out:
# Generating questions...
#
# Evaluating QA pairs...
#
# ('\nWas only able to generate 111 questions.', 'For more questions, please input a longer text.')
# 1) Q: What has resulted in aid not being delivered in a timely manner?
#    A: On numerous occasions, this has resulted in aid not being delivered in a timely manner.
#
# 2) Q: What is the main reason why hospitals and health centers have fallen into disarray?
#    A: As a result, hospitals and health centers around the globe have fallen into disarray.
#
# 3) Q: How does the proposed tool integrate SIA?
#    A: Therefore, the proposed tool would integrate SIA through a wearable voice-activated device that communicates to each individual in a different way.
#
# 4) Q: How will the SIA be kept private?
#    A: As much as possible, our data centers will be encrypted and kept private.
#
# 5) Q: What is the impact of chronic kidney disease on the patient's emotional state?
# ...
